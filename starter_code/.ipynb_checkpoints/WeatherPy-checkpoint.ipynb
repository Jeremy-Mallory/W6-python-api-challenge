# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 655

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        response = requests.get(city_url).json()
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adrar
# Processing Record 2 of Set 1 | tilichiki
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | suoyarvi
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | te anau
# Processing Record 8 of Set 1 | pangody
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | eureka
# Processing Record 13 of Set 1 | ullapool
# Processing Record 14 of Set 1 | raudeberg
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | mayenne
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | vestmannaeyjar
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | sable-sur-sarthe
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | loukhi
# Processing Record 25 of Set 1 | naze
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | alofi
# Processing Record 30 of Set 1 | kresttsy
# Processing Record 31 of Set 1 | srednekolymsk
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | bend
# Processing Record 34 of Set 1 | lagoa
# Processing Record 35 of Set 1 | antalaha
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | lashio
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | aldan
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | khilok
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | whitehaven
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | ahipara
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | oriximina
# Processing Record 0 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | maniitsoq
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | handan
# Processing Record 7 of Set 2 | babynino
# Processing Record 8 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 2 | labuhan
# Processing Record 10 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 2 | thinadhoo
# Processing Record 12 of Set 2 | henderson
# Processing Record 13 of Set 2 | hobyo
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | passagem franca
# Processing Record 17 of Set 2 | calabozo
# Processing Record 18 of Set 2 | nome
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | hot springs
# Processing Record 21 of Set 2 | lagos
# Processing Record 22 of Set 2 | darnah
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | ambovombe
# Processing Record 25 of Set 2 | cahors
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | coihaique
# Processing Record 28 of Set 2 | yerbogachen
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | muzaffarabad
# Processing Record 35 of Set 2 | amos
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | ixtapa
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | kaa-khem
# Processing Record 42 of Set 2 | rio gallegos
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | isla mujeres
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | gornoye loo
# Processing Record 0 of Set 3 | meulaboh
# Processing Record 1 of Set 3 | boshnyakovo
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | dali
# Processing Record 4 of Set 3 | matara
# Processing Record 5 of Set 3 | ailigandi
# Processing Record 6 of Set 3 | bodden town
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | zhigansk
# Processing Record 9 of Set 3 | faridpur
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | yorkton
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | walvis bay
# Processing Record 15 of Set 3 | lafiagi
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | anyang
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 3 | pasni
# Processing Record 21 of Set 3 | rio grande
# Processing Record 22 of Set 3 | banda aceh
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | baker city
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | riyadh
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | moose factory
# Processing Record 31 of Set 3 | ambunti
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | san lorenzo
# Processing Record 36 of Set 3 | tateyama
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | laiagam
# City not found. Skipping...
# Processing Record 41 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 3 | bassano
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | pierre
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | adamovka
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | georgetown
# Processing Record 0 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | itainopolis
# Processing Record 2 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | dipkarpaz
# City not found. Skipping...
# Processing Record 5 of Set 4 | bialystok
# Processing Record 6 of Set 4 | mandalgovi
# Processing Record 7 of Set 4 | san quintin
# Processing Record 8 of Set 4 | harper
# Processing Record 9 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 4 | soubre
# Processing Record 11 of Set 4 | salinopolis
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | rodrigues alves
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | sauga
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | gimli
# Processing Record 19 of Set 4 | broome
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | ngunguru
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | luwuk
# Processing Record 27 of Set 4 | sambava
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | vilhena
# Processing Record 30 of Set 4 | camocim
# Processing Record 31 of Set 4 | najran
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | tynset
# Processing Record 34 of Set 4 | mbanza-ngungu
# Processing Record 35 of Set 4 | campo maior
# Processing Record 36 of Set 4 | acushnet
# Processing Record 37 of Set 4 | mpika
# Processing Record 38 of Set 4 | burica
# City not found. Skipping...
# Processing Record 39 of Set 4 | ola
# Processing Record 40 of Set 4 | college
# Processing Record 41 of Set 4 | mount gambier
# Processing Record 42 of Set 4 | aleysk
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | clifton
# Processing Record 45 of Set 4 | olafsvik
# Processing Record 46 of Set 4 | wenling
# Processing Record 47 of Set 4 | upington
# Processing Record 48 of Set 4 | letlhakane
# Processing Record 49 of Set 4 | tabas
# Processing Record 0 of Set 5 | roblin
# Processing Record 1 of Set 5 | winnemucca
# Processing Record 2 of Set 5 | acari
# Processing Record 3 of Set 5 | port lincoln
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | pundaguitan
# Processing Record 6 of Set 5 | mopipi
# Processing Record 7 of Set 5 | dotnuva
# Processing Record 8 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 9 of Set 5 | necochea
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | leo
# Processing Record 12 of Set 5 | kudahuvadhoo
# Processing Record 13 of Set 5 | sept-iles
# Processing Record 14 of Set 5 | iquitos
# Processing Record 15 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 5 | hamada
# Processing Record 17 of Set 5 | rockhampton
# Processing Record 18 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | kamenka
# Processing Record 22 of Set 5 | zhuhai
# Processing Record 23 of Set 5 | the valley
# Processing Record 24 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 5 | dingle
# Processing Record 26 of Set 5 | iisalmi
# Processing Record 27 of Set 5 | urucara
# Processing Record 28 of Set 5 | aljezur
# Processing Record 29 of Set 5 | bunia
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | qaanaaq
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | torbay
# Processing Record 34 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | lahaina
# Processing Record 37 of Set 5 | russell
# Processing Record 38 of Set 5 | manzil salim
# Processing Record 39 of Set 5 | puerto del rosario
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | maryborough
# Processing Record 42 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 5 | dagda
# Processing Record 44 of Set 5 | qorveh
# Processing Record 45 of Set 5 | shelburne
# Processing Record 46 of Set 5 | juegang
# Processing Record 47 of Set 5 | joshimath
# Processing Record 48 of Set 5 | saint george
# Processing Record 49 of Set 5 | camacha
# Processing Record 0 of Set 6 | batemans bay
# Processing Record 1 of Set 6 | ridgecrest
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | taksimo
# Processing Record 5 of Set 6 | puerto carreno
# Processing Record 6 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 6 | lebork
# Processing Record 8 of Set 6 | mecca
# Processing Record 9 of Set 6 | hays
# Processing Record 10 of Set 6 | douglas
# Processing Record 11 of Set 6 | le port
# Processing Record 12 of Set 6 | nayoro
# Processing Record 13 of Set 6 | ustyuzhna
# Processing Record 14 of Set 6 | hammerfest
# Processing Record 15 of Set 6 | nakusp
# Processing Record 16 of Set 6 | nove hrady
# Processing Record 17 of Set 6 | caala
# Processing Record 18 of Set 6 | oktyabrskoye
# Processing Record 19 of Set 6 | nybro
# Processing Record 20 of Set 6 | kristiansund
# Processing Record 21 of Set 6 | kapit
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | beya
# Processing Record 24 of Set 6 | pangai
# Processing Record 25 of Set 6 | port elizabeth
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | moorhead
# Processing Record 28 of Set 6 | baherden
# Processing Record 29 of Set 6 | kita
# Processing Record 30 of Set 6 | turukhansk
# Processing Record 31 of Set 6 | honiara
# Processing Record 32 of Set 6 | hofn
# Processing Record 33 of Set 6 | requena
# Processing Record 34 of Set 6 | harstad
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | vitim
# Processing Record 37 of Set 6 | bom jesus
# Processing Record 38 of Set 6 | hervey bay
# Processing Record 39 of Set 6 | hailar
# Processing Record 40 of Set 6 | ipil
# Processing Record 41 of Set 6 | sheridan
# Processing Record 42 of Set 6 | ribeira grande
# Processing Record 43 of Set 6 | klaksvik
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | hamakita
# Processing Record 46 of Set 6 | sola
# Processing Record 47 of Set 6 | guasdualito
# Processing Record 48 of Set 6 | vaitape
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 0 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 7 | vila velha
# Processing Record 2 of Set 7 | sao felix do xingu
# Processing Record 3 of Set 7 | la sarre
# Processing Record 4 of Set 7 | marsa matruh
# Processing Record 5 of Set 7 | naryan-mar
# Processing Record 6 of Set 7 | grants pass
# Processing Record 7 of Set 7 | olga
# Processing Record 8 of Set 7 | sakaiminato
# Processing Record 9 of Set 7 | ahuimanu
# Processing Record 10 of Set 7 | northam
# Processing Record 11 of Set 7 | bambanglipuro
# Processing Record 12 of Set 7 | sitka
# Processing Record 13 of Set 7 | bowen
# Processing Record 14 of Set 7 | mayo
# Processing Record 15 of Set 7 | narsaq
# Processing Record 16 of Set 7 | mirabad
# Processing Record 17 of Set 7 | kruisfontein
# Processing Record 18 of Set 7 | ayagoz
# Processing Record 19 of Set 7 | osypenko
# Processing Record 20 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 7 | chulym
# Processing Record 22 of Set 7 | wellin
# Processing Record 23 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 7 | lavrentiya
# Processing Record 25 of Set 7 | dawson creek
# Processing Record 26 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | ondjiva
# Processing Record 29 of Set 7 | nemuro
# Processing Record 30 of Set 7 | samarai
# Processing Record 31 of Set 7 | saint-pierre
# Processing Record 32 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 7 | chapleau
# Processing Record 34 of Set 7 | talcahuano
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | shushtar
# Processing Record 38 of Set 7 | nosy varika
# Processing Record 39 of Set 7 | ouallam
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | airai
# Processing Record 44 of Set 7 | hami
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | griffith
# Processing Record 48 of Set 7 | yauya
# Processing Record 49 of Set 7 | urumqi
# Processing Record 0 of Set 8 | oranjemund
# Processing Record 1 of Set 8 | guilin
# Processing Record 2 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 8 | rochester
# Processing Record 4 of Set 8 | jasper
# Processing Record 5 of Set 8 | kloulklubed
# Processing Record 6 of Set 8 | amparafaravola
# Processing Record 7 of Set 8 | rassvet
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | jijiga
# Processing Record 10 of Set 8 | ketchikan
# Processing Record 11 of Set 8 | kavaratti
# Processing Record 12 of Set 8 | santander jimenez
# Processing Record 13 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 8 | gorkovskoye
# City not found. Skipping...
# Processing Record 15 of Set 8 | sabinas
# Processing Record 16 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 8 | aykhal
# Processing Record 18 of Set 8 | dongsheng
# Processing Record 19 of Set 8 | kununurra
# Processing Record 20 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 21 of Set 8 | shimoda
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | cairns
# Processing Record 25 of Set 8 | vila franca do campo
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | doha
# Processing Record 28 of Set 8 | takoradi
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 8 | pedernales
# Processing Record 32 of Set 8 | tembisa
# Processing Record 33 of Set 8 | puerto escondido
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | high level
# Processing Record 36 of Set 8 | kocevje
# Processing Record 37 of Set 8 | fukue
# Processing Record 38 of Set 8 | sao filipe
# Processing Record 39 of Set 8 | bubaque
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | puerto maldonado
# Processing Record 42 of Set 8 | athabasca
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | sabang
# Processing Record 45 of Set 8 | sungaipenuh
# Processing Record 46 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 47 of Set 8 | vysotsk
# Processing Record 48 of Set 8 | cacoal
# Processing Record 49 of Set 8 | tucumcari
# Processing Record 0 of Set 9 | christchurch
# Processing Record 1 of Set 9 | lata
# Processing Record 2 of Set 9 | port augusta
# Processing Record 3 of Set 9 | pevek
# Processing Record 4 of Set 9 | uruzgan
# Processing Record 5 of Set 9 | yuncheng
# Processing Record 6 of Set 9 | saint anthony
# Processing Record 7 of Set 9 | pandan niog
# Processing Record 8 of Set 9 | namatanai
# Processing Record 9 of Set 9 | acapulco
# Processing Record 10 of Set 9 | fairbanks
# Processing Record 11 of Set 9 | san isidro
# Processing Record 12 of Set 9 | whakatane
# Processing Record 13 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 9 | sarkand
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | tigil
# Processing Record 17 of Set 9 | dukat
# Processing Record 18 of Set 9 | aklavik
# Processing Record 19 of Set 9 | kadoma
# Processing Record 20 of Set 9 | kamen-na-obi
# Processing Record 21 of Set 9 | parana
# Processing Record 22 of Set 9 | geraldton
# Processing Record 23 of Set 9 | sanming
# Processing Record 24 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 9 | imbituba
# Processing Record 26 of Set 9 | yar-sale
# Processing Record 27 of Set 9 | huarmey
# Processing Record 28 of Set 9 | kahramanmaras
# Processing Record 29 of Set 9 | hokitika
# Processing Record 30 of Set 9 | jacareacanga
# Processing Record 31 of Set 9 | omboue
# Processing Record 32 of Set 9 | selma
# Processing Record 33 of Set 9 | quatre cocos
# Processing Record 34 of Set 9 | fredonia
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | caloundra
# Processing Record 37 of Set 9 | mana
# Processing Record 38 of Set 9 | ulaangom
# Processing Record 39 of Set 9 | manali
# Processing Record 40 of Set 9 | bogatyye saby
# Processing Record 41 of Set 9 | coxim
# Processing Record 42 of Set 9 | matay
# Processing Record 43 of Set 9 | tiarei
# Processing Record 44 of Set 9 | tromso
# Processing Record 45 of Set 9 | price
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | sorland
# Processing Record 48 of Set 9 | obera
# Processing Record 49 of Set 9 | baghdad
# Processing Record 0 of Set 10 | saint-joseph
# Processing Record 1 of Set 10 | hasaki
# Processing Record 2 of Set 10 | chabahar
# Processing Record 3 of Set 10 | sokolo
# Processing Record 4 of Set 10 | zwedru
# Processing Record 5 of Set 10 | shingu
# Processing Record 6 of Set 10 | meadow lake
# Processing Record 7 of Set 10 | magaria
# Processing Record 8 of Set 10 | itarema
# Processing Record 9 of Set 10 | osorno
# Processing Record 10 of Set 10 | san-pedro
# Processing Record 11 of Set 10 | gillette
# Processing Record 12 of Set 10 | plouzane
# Processing Record 13 of Set 10 | hit
# Processing Record 14 of Set 10 | xuddur
# Processing Record 15 of Set 10 | pa sang
# Processing Record 16 of Set 10 | fort nelson
# Processing Record 17 of Set 10 | esperance
# Processing Record 18 of Set 10 | waipawa
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | khotyn
# Processing Record 21 of Set 10 | rawson
# Processing Record 22 of Set 10 | iqaluit
# Processing Record 23 of Set 10 | coquimbo
# Processing Record 24 of Set 10 | boa vista
# Processing Record 25 of Set 10 | half moon bay
# Processing Record 26 of Set 10 | kerchevskiy
# Processing Record 27 of Set 10 | belyy yar
# Processing Record 28 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 10 | sibolga
# Processing Record 30 of Set 10 | manono
# Processing Record 31 of Set 10 | moengo
# Processing Record 32 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 10 | warri
# Processing Record 34 of Set 10 | bima
# Processing Record 35 of Set 10 | sholokhove
# Processing Record 36 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | togur
# Processing Record 39 of Set 10 | katherine
# Processing Record 40 of Set 10 | mahibadhoo
# Processing Record 41 of Set 10 | atasu
# Processing Record 42 of Set 10 | valparaiso
# Processing Record 43 of Set 10 | marzuq
# Processing Record 44 of Set 10 | inuvik
# Processing Record 45 of Set 10 | rennes
# Processing Record 46 of Set 10 | bago
# Processing Record 47 of Set 10 | kumo
# Processing Record 48 of Set 10 | beyneu
# Processing Record 49 of Set 10 | orocovis
# Processing Record 0 of Set 11 | mogadishu
# Processing Record 1 of Set 11 | rock hill
# Processing Record 2 of Set 11 | khor
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | yele
# Processing Record 5 of Set 11 | brae
# Processing Record 6 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 11 | bodo
# Processing Record 8 of Set 11 | charters towers
# Processing Record 9 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 10 of Set 11 | killin
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | curitibanos
# Processing Record 13 of Set 11 | xam nua
# Processing Record 14 of Set 11 | nioro
# Processing Record 15 of Set 11 | prince rupert
# Processing Record 16 of Set 11 | champerico
# Processing Record 17 of Set 11 | noyabrsk
# Processing Record 18 of Set 11 | waw
# Processing Record 19 of Set 11 | koslan
# Processing Record 20 of Set 11 | zhanaozen
# Processing Record 21 of Set 11 | kahului
# Processing Record 22 of Set 11 | erzin
# Processing Record 23 of Set 11 | amudat
# Processing Record 24 of Set 11 | byron bay
# Processing Record 25 of Set 11 | oyama
# Processing Record 26 of Set 11 | chissamba
# Processing Record 27 of Set 11 | kyzyl-suu
# Processing Record 28 of Set 11 | santa rosa
# Processing Record 29 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 11 | kupang
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | tabou
# Processing Record 33 of Set 11 | maralal
# Processing Record 34 of Set 11 | kaeo
# Processing Record 35 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 36 of Set 11 | deputatskiy
# Processing Record 37 of Set 11 | redmond
# Processing Record 38 of Set 11 | palana
# Processing Record 39 of Set 11 | eenhana
# Processing Record 40 of Set 11 | qaqortoq
# Processing Record 41 of Set 11 | gizo
# Processing Record 42 of Set 11 | whitehorse
# Processing Record 43 of Set 11 | kholtoson
# Processing Record 44 of Set 11 | honningsvag
# Processing Record 45 of Set 11 | tautira
# Processing Record 46 of Set 11 | qurayyat
# Processing Record 47 of Set 11 | kencong
# Processing Record 48 of Set 11 | akhmim
# Processing Record 49 of Set 11 | casper
# Processing Record 0 of Set 12 | rebrikha
# Processing Record 1 of Set 12 | fallon
# Processing Record 2 of Set 12 | camopi
# Processing Record 3 of Set 12 | sylvan lake
# Processing Record 4 of Set 12 | babu
# Processing Record 5 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 12 | antofagasta
# Processing Record 7 of Set 12 | georgiyevskoye
# Processing Record 8 of Set 12 | nishihara
# Processing Record 9 of Set 12 | acuautla
# Processing Record 10 of Set 12 | edson
# Processing Record 11 of Set 12 | fethiye
# Processing Record 12 of Set 12 | andenes
# Processing Record 13 of Set 12 | xinzhi
# Processing Record 14 of Set 12 | znamenskoye
# Processing Record 15 of Set 12 | natal
# Processing Record 16 of Set 12 | buala
# Processing Record 17 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 18 of Set 12 | buckeye
# Processing Record 19 of Set 12 | sao miguel do araguaia
# Processing Record 20 of Set 12 | vanavara
# Processing Record 21 of Set 12 | ifanadiana
# Processing Record 22 of Set 12 | wellington
# Processing Record 23 of Set 12 | papar
# Processing Record 24 of Set 12 | tiznit
# Processing Record 25 of Set 12 | presidencia roque saenz pena
# Processing Record 26 of Set 12 | chernyshevskiy
# Processing Record 27 of Set 12 | barabai
# Processing Record 28 of Set 12 | talnakh
# Processing Record 29 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 12 | lazaro cardenas
# Processing Record 31 of Set 12 | cap-aux-meules
# Processing Record 32 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 12 | yarmouth
# Processing Record 35 of Set 12 | rovaniemi
# Processing Record 36 of Set 12 | pucallpa
# Processing Record 37 of Set 12 | lander
# Processing Record 38 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 12 | gravdal
# Processing Record 40 of Set 12 | krasnoselkup
# Processing Record 41 of Set 12 | tottori
# Processing Record 42 of Set 12 | bondo
# Processing Record 43 of Set 12 | san andres
# Processing Record 44 of Set 12 | bennettsville
# Processing Record 45 of Set 12 | lahan
# Processing Record 46 of Set 12 | alunitdag
# City not found. Skipping...
# Processing Record 47 of Set 12 | jizan
# Processing Record 48 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 49 of Set 12 | alindao
# Processing Record 0 of Set 13 | baturite
# Processing Record 1 of Set 13 | gua musang
# Processing Record 2 of Set 13 | kucevo
# Processing Record 3 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 13 | changde
# Processing Record 5 of Set 13 | pires do rio
# Processing Record 6 of Set 13 | dicabisagan
# Processing Record 7 of Set 13 | nyazepetrovsk
# Processing Record 8 of Set 13 | dalian
# Processing Record 9 of Set 13 | carlos chagas
# Processing Record 10 of Set 13 | dolores
# Processing Record 11 of Set 13 | monaragala
# Processing Record 12 of Set 13 | sampit
# Processing Record 13 of Set 13 | mao
# Processing Record 14 of Set 13 | myaundzha
# Processing Record 15 of Set 13 | azoyu
# Processing Record 16 of Set 13 | tarakan
# Processing Record 17 of Set 13 | nago
# Processing Record 18 of Set 13 | sorrento
# Processing Record 19 of Set 13 | fonte boa
# Processing Record 20 of Set 13 | fushun
# Processing Record 21 of Set 13 | manokwari
# Processing Record 22 of Set 13 | touros
# Processing Record 23 of Set 13 | lasa
# Processing Record 24 of Set 13 | makakilo city
# Processing Record 25 of Set 13 | bejar
# Processing Record 26 of Set 13 | otorohanga
# Processing Record 27 of Set 13 | sabancuy
# Processing Record 28 of Set 13 | llangefni
# Processing Record 29 of Set 13 | phayakkhaphum phisai
# Processing Record 30 of Set 13 | korla
# Processing Record 31 of Set 13 | simbahan
# Processing Record 32 of Set 13 | manaure
# Processing Record 33 of Set 13 | bud
# Processing Record 34 of Set 13 | yumen
# Processing Record 35 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 13 | shahdol
# Processing Record 37 of Set 13 | pimentel
# Processing Record 38 of Set 13 | sakakah
# Processing Record 39 of Set 13 | dunda
# Processing Record 40 of Set 13 | groningen
# Processing Record 41 of Set 13 | aswan
# Processing Record 42 of Set 13 | ostrovnoy
# Processing Record 43 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 13 | namie
# Processing Record 45 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 13 | colares
# Processing Record 48 of Set 13 | bati
# Processing Record 49 of Set 13 | sao jose da coroa grande
# Processing Record 0 of Set 14 | north bend
# Processing Record 1 of Set 14 | baijiantan
# Processing Record 2 of Set 14 | lorengau
# Processing Record 3 of Set 14 | nokaneng
# Processing Record 4 of Set 14 | boende
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({ 
                "City" : city_name,
                "Lat" : lat,
                "Lng" : lng,
                "Max Temp" : max_temp,
                "Humidity" : humidity,
                "Cloudiness" : clouds,
                "Wind Speed" : wind_speed,
                "Country" : country,
                "Date" : date})

# Show Record Count
city_data_df.count()
# Out:
# City          594
# Lat           594
# Lng           594
# Max Temp      594
# Humidity      594
# Cloudiness    594
# Wind Speed    594
# Country       594
# Date          594
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Adrar  20.5022  -10.0711     89.42        19           0        9.91
# 1  Tilichiki  60.4667  166.1000     30.20        98         100       14.20
# 2     Albany  42.6001  -73.9662     59.18        90         100        7.85
# 3   Suoyarvi  62.0833   32.3500     40.51        85          87        2.55
# 4      Bluff -46.6000  168.3333     52.81        79         100        9.86
#
#   Country        Date
# 0      MR  1681734041
# 1      RU  1681733880
# 2      US  1681734042
# 3      RU  1681734042
# 4      NZ  1681734042

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            Adrar  20.5022  -10.0711     89.42        19           0
# 1        Tilichiki  60.4667  166.1000     30.20        98         100
# 2           Albany  42.6001  -73.9662     59.18        90         100
# 3         Suoyarvi  62.0833   32.3500     40.51        85          87
# 4            Bluff -46.6000  168.3333     52.81        79         100
#
#          Wind Speed Country        Date
# City_ID
# 0              9.91      MR  1681734041
# 1             14.20      RU  1681733880
# 2              7.85      US  1681734042
# 3              2.55      RU  1681734042
# 4              9.86      NZ  1681734042

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'] , city_data_df['Max Temp'] , marker = "o", facecolors = "blue", alpha = .75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'] , city_data_df['Humidity'] , marker = "o", facecolors = "blue", alpha = .75)


# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'] , city_data_df['Cloudiness'] , marker = "o", facecolors = "blue", alpha = .75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'] , city_data_df['Wind Speed'] , marker = "o", facecolors = "blue", alpha = .75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi = city_data_df.loc[city_data_df["Lat"] >= 0, :]
northern_hemi_df = pd.DataFrame(northern_hemi)
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            Adrar  20.5022  -10.0711     89.42        19           0
# 1        Tilichiki  60.4667  166.1000     30.20        98         100
# 2           Albany  42.6001  -73.9662     59.18        90         100
# 3         Suoyarvi  62.0833   32.3500     40.51        85          87
# 6          Pangody  65.8500   74.4859     14.04        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              9.91      MR  1681734041
# 1             14.20      RU  1681733880
# 2              7.85      US  1681734042
# 3              2.55      RU  1681734042
# 6             12.75      RU  1681734043

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi = city_data_df.loc[city_data_df["Lat"] < 0, :]
southern_hemi_df = pd.DataFrame(southern_hemi)

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4               Bluff -46.6000  168.3333     52.81        79         100
# 5             Te Anau -45.4167  167.7167     55.04        77         100
# 7             Mataura -46.1927  168.8643     52.48        73         100
# 8        Punta Arenas -53.1500  -70.9167     37.51        87         100
# 9            Hermanus -34.4187   19.2345     67.86        60           2
#
#          Wind Speed Country        Date
# City_ID
# 4              9.86      NZ  1681734042
# 5              3.20      NZ  1681733841
# 7              2.59      NZ  1681734044
# 8             17.27      CL  1681733953
# 9              2.51      ZA  1681734044

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Northern Hemisphere Cities - Max Temp vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig5.png")
# Out:
# Regression line equation is: y = -1.08x +98.06
# The r-value is: 0.7218381154363559

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Southern Hemisphere Cities - Max Temp vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig6.png")
# Out:
# Regression line equation is: y = 0.62x +84.71
# The r-value is: 0.47369567986753197

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong correlation between latitude and temperature. As latitude increases towards 0 in the southern hemisphere, temperatures rise. Conversely as latitude dcreases towards 0 in the northern hemisphere, temperature also decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Northern Hemisphere Cities - Humidity vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig7.png")
# Out:
# Regression line equation is: y = 0.36x +51.6
# The r-value is: 0.08526304750953491

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Southern Hemisphere Cities - Humidity vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig8.png")
# Out:
# Regression line equation is: y = 0.22x +80.53
# The r-value is: 0.030654200355709094

# %% [markdown]
# **Discussion about the linear relationship:** There is very little correlation between latitude and humity in either hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Northern Hemisphere Cities - Cloudiness vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('CLoudiness (%)')
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig9.png")
# Out:
# Regression line equation is: y = 0.51x +37.81
# The r-value is: 0.0675187124862879

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Southern Hemisphere Cities - Cloudiness vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig10.png")
# Out:
# Regression line equation is: y = 0.82x +75.64
# The r-value is: 0.08932054280632809

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no correlation between cloudiness and latitude in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Northern Hemisphere Cities - Wind Speed vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.annotate(line_eq,(0,27),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig11.png")
# Out:
# Regression line equation is: y = 0.04x +6.67
# The r-value is: 0.022557576332192332

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")

plt.scatter(x, y, facecolor="blue")
plt.plot(x, regress_values ,"r-")
plt.title("Southern Hemisphere Cities - Wind Speed vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.annotate(line_eq,(-55,22),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/Fig12.png")
# Out:
# Regression line equation is: y = -0.1x +4.45
# The r-value is: 0.08140121866891836

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between wind speed and latitude in northern hemisphere cities. There is little to no correlation in southern hemisphere cities.
